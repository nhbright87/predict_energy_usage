# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
balance = pd.read_csv('data/EIA930_BALANCE_2020_Jan_Jun.csv', low_memory=False)
pd.set_option('display.max_columns', 25)

# %%
balance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279668 entries, 0 to 279667
# Data columns (total 23 columns):
#  #   Column                                                  Non-Null Count   Dtype
# ---  ------                                                  --------------   -----
#  0   Balancing Authority                                     279668 non-null  object
#  1   Data Date                                               279668 non-null  object
#  2   Hour Number                                             279668 non-null  int64
#  3   Local Time at End of Hour                               279668 non-null  object
#  4   UTC Time at End of Hour                                 279668 non-null  object
#  5   Demand Forecast (MW)                                    226419 non-null  object
#  6   Demand (MW)                                             230435 non-null  object
#  7   Net Generation (MW)                                     273855 non-null  object
# ...

# %%
balance.head()
# Out:
#   Balancing Authority   Data Date  Hour Number Local Time at End of Hour  \
# 0                 AEC  01/01/2020            1     01/01/2020 1:00:00 AM
# 1                 AEC  01/01/2020            2     01/01/2020 2:00:00 AM
# 2                 AEC  01/01/2020            3     01/01/2020 3:00:00 AM
# 3                 AEC  01/01/2020            4     01/01/2020 4:00:00 AM
# 4                 AEC  01/01/2020            5     01/01/2020 5:00:00 AM
#
#   UTC Time at End of Hour Demand Forecast (MW) Demand (MW)  \
# 0   01/01/2020 7:00:00 AM                1,082         549
# 1   01/01/2020 8:00:00 AM                1,084         549
# 2   01/01/2020 9:00:00 AM                1,103         554
# 3  01/01/2020 10:00:00 AM                1,127         565
# 4  01/01/2020 11:00:00 AM                1,179         575
#
#   Net Generation (MW) Total Interchange (MW) Sum(Valid DIBAs) (MW)  \
# 0                 722                    173                   173
# ...

# %%
auth = balance['Balancing Authority'].value_counts()

# %%
plt.hist(auth)
matplotlib.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-584578cbdb3d> in <module>
#       1 plt.hist(auth)
# ----> 2 matplotlib.show()
#
# NameError: name 'matplotlib' is not defined
